# %% [markdown]
# ## This notebook is based on the video from Rob Mulla
# ### Link to video https://www.youtube.com/watch?v=xi0vhXFPegw

# %% [markdown]
# ### Step 0 Importing dependencies and reading data

# %%
# Dependencies
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# Make this directory the current working directory
import os
os.chdir(r'\Users\MaxVästhav\Documents\GitHub\Exploratory-Data-Analysis-with-Python-Pandas-2023')

# %%
# Stylesheet for matplotlib and seaborn charts
plt.style.use('ggplot')

# Expand the number of columns shown in our dataframe. Pandas by default does not show all columns
pd.set_option("display.max_columns", 200)

# %%
# Read the data coaster.csv into a dataframe called df
df = pd.read_csv(r'C:\Users\MaxVästhav\Documents\GitHub\Exploratory-Data-Analysis-with-Python-Pandas-2023\coaster_db.csv')

# %% [markdown]
# ### Step 1: Data Understanding
#
# * Dataframe Shape
# * Head and Tail
# * dtypes
# * describe

# %%
# Tell use the shape of the dataframe
df.shape
# Out:
# (1087, 56)

# %%
# Head gives me the top 5 rows of the dataset
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
# Tail gives me the bottom 5 rows of the dataset
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
# See all the columns listed
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# What Data Type exists inside the dataframe
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
# The describe function gives us basic statistics on the dataframe such as count, mean, std etc of all the columns
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### Step 2: Data Preparation
# * Dropping irrelevant columns and rows
# * Identifying duplicated columns
# * Renaming columns
# * Feature Creation

# %%
# Identify which columns to remove
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %% [markdown]
# For example, Length and Speed contain string values, but there are columns that contain the same information but in a numerical format - therefore it would make more sense to keep the numerical columns and remove the string value columns.

# %%
# Example 1: Subsetting using .columns
# By using the .columns function we can also subset the columns 
# we actually want from a dataset by pasting in and removing related columns from the output of df.columns
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# Using the output instead of .columns
df[['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
       'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
       'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       'Track layout', 'Fastrack available', 'Soft opening date.1',
       'Closing date', 'Opened', 'Replaced by', 'Website',
       'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       'Single rider line available', 'Restraint Style',
       'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 'height_value', 'height_unit', 'height_ft',
       'Inversions_clean', 'Gforce_clean']]
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df[['coaster_name', 
    #'Length', 'Speed', 
    'Location', 'Status', 
    #'Opening date',
     #  'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Durat¨ion', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', #'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']]
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
# Example 2: Subsetting using .drop function
# Using .drop, we can select a column (or row) to exclude from the dataframe.
# For example, using Opening date as the column name withing drop will remove it from the df
# axis=1 is used to tell the function to remove a column, not a row
df.drop(['Opening date'], axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
# With the first subset method, we also have to reassign our dataframe with this new subset of columns.
df = df[['coaster_name', 
    #'Length', 'Speed', 
    'Location', 'Status', 
    #'Opening date',
     #  'Type', 
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Durat¨ion', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
       #'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
       #'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', #'Opened', 'Replaced by', 'Website',
       #'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
       #'Single rider line available', 'Restraint Style',
       #'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
# Now we only have 13 columns but the same amount of rows.
# An error in this dataframe is the 'opening_date_clean', its seen as an object but it's a date!
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
# Let's fix this by changing opening_date_clean to date time instead using the pandas function
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
# Rename the columns 
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
# Use .rename(columns={}) where the {} is a dictionary for the function
df = df.rename(columns={'coaster_name':'Coaster_Name', 
                   'year_introduced':'Year_Introduced',
                   'latitude':'Latitude',
                   'longitude':'Longitude',
                   'opening_date_clean':'Opening_Date',
                   'speed_mph':'Speed_Mph',
                   'height_ft':'Height_Ft',
                   'Inversions_clean':'Inversions',
                   'Gforce_clean':'Gforce'
                  })

# %%
# Lets now look for missing values by using the .isna() function
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_Mph          150
# Height_Ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
# And duplicated values
print(df.duplicated())
df.loc[df.duplicated()]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed_Mph, Height_Ft, Inversions, Gforce]
# Index: []

# %%
# So there are no duplicated entire rows, but what about inside the columns?
# by using subset we can look inside a singular column
# the duplicated function by default shows the second value (the duplicated/repeated)
df.loc[df.duplicated(subset='Coaster_Name')].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# ...

# %%
# Let's take a look as to why this could be, lets use Crystal Beach Cyclone as an example
# We'll use the query function
df.query('Coaster_Name == "Crystal Beach Cyclone"')

# They look almost identical, however the "Year_Introduced" has two values
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_Ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph',
#        'Height_Ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
# Lets remove data that has certain number of columns that are the same
# Identify number of rows which have duplicated 
df.duplicated(subset=['Coaster_Name','Location','Opening_Date']).sum()
# Out:
# 97

# %%
# We can then take the inverse of this by using ~ before the code
~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])

# Notice how the False have switched to True and vice versa?
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1082    False
# 1083     True
# 1084    False
# 1085     True
# 1086     True
# Length: 1087, dtype: bool

# %%
# By using this inverse we can get only the rows without duplicated values. 
# However, this is messing up our index as rows are dissapearing, lets fix that!
df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])]
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
# by using .reset_index() we can reset the index to the actual number of rows
# the (drop=True) is used to not add an index column to the dataframe
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])] \
    .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# ### Step 3: Feature Understanding
# This is where the fun begins :)
#
# (Univariate analysis)
# * Plotting Feature Distributions
#     * Histogram
#     * KDE
#     * Boxplot

# %%
# Lets look at each feature by itself, starting with Year Introduced
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
# Plot a column with the value_counts() and save it as a Matplotlib Axes
ax = df['Year_Introduced'].value_counts() \
    .head(10).plot(kind='bar',title='Top 10 Years Coasters')
# When we save it as an axes, we can perform additional function on the plot
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Number of Coasters')
# Out:
# Text(0, 0.5, 'Number of Coasters')

# %%
# When working with one column of data, there are other things we might wanna do - for example the
# distribution of data
ax = df['Speed_Mph'].plot(kind='hist', 
                          bins=20, 
                          title='Coaster Speed (MPH)') 
ax.set_xlabel('Speed (MPH)')
# Out:
# Text(0.5, 0, 'Speed (MPH)')

# %%
# This is different from the distribution graph, a density plot (read kde as kind of graph)
# It's less cluttered and easier to read as all values are normalized
ax = df['Speed_Mph'].plot(kind='kde',  
                          title='Coaster Speed (MPH)') 
ax.set_xlabel('Speed (MPH)')
# Out:
# Text(0.5, 0, 'Speed (MPH)')

# %% [markdown]
# ### Step 4: Feature Relationships
# * Scatterplot
# * Heatmap Correlation
# * Pairplot
# * Groupby comparisons

# %%
# Using Matplotlib
df.plot(kind='scatter', 
        x='Speed_Mph', 
        y='Height_Ft', 
        title='Speed (MPH) vs Height (FT)')
plt.show()

# %%
sns.scatterplot(
    x='Speed_Mph', 
    y='Height_Ft',
    hue='Year_Introduced',
    data=df 
)
# Out:
# <Axes: xlabel='Speed_Mph', ylabel='Height_Ft'>

# %%
# Seaborns Pairplot is great for finding a lot of insights quickly beteween multiple variables
sns.pairplot(
    kind='scatter',
    data=df,
    vars=['Year_Introduced', 'Speed_Mph', 'Height_Ft', 'Inversions', 'Gforce'],
    hue='Type_Main'
)
plt.show()

# %%
# Correlation between values
df_corr = df[['Year_Introduced', 'Speed_Mph', 'Height_Ft', 'Inversions', 'Gforce']].dropna().corr()
df_corr
# Out:
#                  Year_Introduced  Speed_Mph  Height_Ft  Inversions    Gforce
# Year_Introduced         1.000000   0.171978   0.135413   -0.209887  0.160247
# Speed_Mph               0.171978   1.000000   0.733999   -0.028705  0.607383
# Height_Ft               0.135413   0.733999   1.000000   -0.079736  0.466482
# Inversions             -0.209887  -0.028705  -0.079736    1.000000  0.275991
# Gforce                  0.160247   0.607383   0.466482    0.275991  1.000000

# %%
# Seaborn Heatmap
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Step 5: Ask a Question about the data
# * Try to answer a question you have about the data using a plot or statistic
#
# A column we haven't really looked at is Location
# Q: What are the locations with the fastest roller coasters with a minimum of 10 coasters per location

# %%
# How many locations are there?
df['Location'].value_counts()
# Out:
# Location
# Other                            181
# Kings Island                      19
# Cedar Point                       18
# Six Flags Magic Mountain          17
# Hersheypark                       16
#                                 ...
# Granada Studios Tour               1
# Funtown Splashtown USA             1
# Tolchester Beach Park              1
# Suzuka, Mie Prefecture, Japan      1
# Epcot                              1
# Name: count, Length: 280, dtype: int64

# %%
# We can see 'Other' is the most common location, but its not really a location so lets filter that out
df.query('Location != "Other"') \
    .groupby('Location')['Speed_Mph'] \
    .agg(['mean', 'count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean']
# Out:
# Location
# Alton Towers                  42.791667
# Carowinds                     43.571429
# Kings Island                  49.273684
# Hersheypark                   50.576923
# Kings Dominion                52.083333
# Six Flags Great Adventure     53.036364
# Canada's Wonderland           53.533333
# Six Flags Magic Mountain      57.241176
# Cedar Point                   57.833333
# Busch Gardens Williamsburg    58.318182
# Name: mean, dtype: float64

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_Mph'] \
    .agg(['mean', 'count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Cost Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
